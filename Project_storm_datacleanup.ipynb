# %%
import pandas as pd
from sqlalchemy import create_engine 
import datetime as dt

# %%
# Importing csv

storm_csv = pd.read_csv('data/Storms_2020.csv')
storm_csv.head()
# Out:
# C:\Users\ana_m\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (16,17,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    event_id     state event_type   cz_name event_begin_time event_timezone  \
# 0    865452  Oklahoma       hail     TULSA  1/10/2020 11:35          CST-6
# 1    865453  Oklahoma       hail     TULSA  1/10/2020 11:36          CST-6
# 2    865454  Oklahoma       hail     TULSA  1/10/2020 11:38          CST-6
# 3    865455  Oklahoma       hail  CHEROKEE  1/10/2020 15:02          CST-6
# 4    865712     Texas       hail      HAYS  1/10/2020 19:40          CST-6
#
#     event_end_time  injuries_direct  injuries_indirect  deaths_direct  ...  \
# 0  1/10/2020 11:35                0                  0              0  ...
# 1  1/10/2020 11:36                0                  0              0  ...
# 2  1/10/2020 11:38                0                  0              0  ...
# 3  1/10/2020 15:02                0                  0              0  ...
# 4  1/10/2020 19:40                0                  0              0  ...
#
#    tor_length  tor_width  tor_other_wfo location_index  event_range  \
# 0         NaN          0            NaN            1.0         0.24
# 1         NaN          0            NaN            1.0         2.95
# 2         NaN          0            NaN            1.0         2.00
# 3         NaN          0            NaN            1.0         0.65
# 4         NaN          0            NaN            1.0         5.01
#
#   event_azimuth    reference_location event_latitude  event_longitude  \
# 0           ENE                 TULSA        36.1514         -95.9460
# 1           NNE  TULSA R L JONES ARPT        36.0690         -95.9585
# 2             N                 TULSA        36.1790         -95.9500
# 3             S             TAHLEQUAH        35.9106         -94.9710
# 4           ENE                 HENLY        30.2400         -98.1500
#
#               event_point
# 0  POINT(-95.946 36.1514)
# 1  POINT(-95.9585 36.069)
# 2    POINT(-95.95 36.179)
# 3  POINT(-94.971 35.9106)
# 4     POINT(-98.15 30.24)
#
# [5 rows x 28 columns]

# %%
storm_csv.columns
# Out:
# Index(['event_id', 'state', 'event_type', 'cz_name', 'event_begin_time',
#        'event_timezone', 'event_end_time', 'injuries_direct',
#        'injuries_indirect', 'deaths_direct', 'deaths_indirect',
#        'damage_property', 'damage_crops', 'source', 'magnitude',
#        'magnitude_type', 'flood_cause', 'tor_f_scale', 'tor_length',
#        'tor_width', 'tor_other_wfo', 'location_index', 'event_range',
#        'event_azimuth', 'reference_location', 'event_latitude',
#        'event_longitude', 'event_point'],
#       dtype='object')

# %%
# selecting the columns we want

new_stormcsv = storm_csv[['event_id', 'state', 'event_type','event_begin_time',
       'event_timezone', 'event_end_time','injuries_direct',
       'injuries_indirect', 'deaths_direct', 'deaths_indirect',
       'damage_property', 'damage_crops','magnitude','event_latitude',
       'event_longitude']]
new_stormcsv.head()
# Out:
#    event_id     state event_type event_begin_time event_timezone  \
# 0    865452  Oklahoma       hail  1/10/2020 11:35          CST-6
# 1    865453  Oklahoma       hail  1/10/2020 11:36          CST-6
# 2    865454  Oklahoma       hail  1/10/2020 11:38          CST-6
# 3    865455  Oklahoma       hail  1/10/2020 15:02          CST-6
# 4    865712     Texas       hail  1/10/2020 19:40          CST-6
#
#     event_end_time  injuries_direct  injuries_indirect  deaths_direct  \
# 0  1/10/2020 11:35                0                  0              0
# 1  1/10/2020 11:36                0                  0              0
# 2  1/10/2020 11:38                0                  0              0
# 3  1/10/2020 15:02                0                  0              0
# 4  1/10/2020 19:40                0                  0              0
#
#    deaths_indirect  damage_property  damage_crops  magnitude  event_latitude  \
# 0                0              0.0           0.0       1.00         36.1514
# 1                0              0.0           0.0       1.00         36.0690
# 2                0              0.0           0.0       0.75         36.1790
# 3                0          15000.0           0.0       1.75         35.9106
# 4                0              0.0           0.0       0.75         30.2400
#
#    event_longitude
# 0         -95.9460
# 1         -95.9585
# 2         -95.9500
# 3         -94.9710
# 4         -98.1500

# %%
#identifying types for each column
new_stormcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40037 entries, 0 to 40036
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_id           40037 non-null  int64
#  1   state              40037 non-null  object
#  2   event_type         40037 non-null  object
#  3   event_begin_time   40037 non-null  object
#  4   event_timezone     40037 non-null  object
#  5   event_end_time     40037 non-null  object
#  6   injuries_direct    40037 non-null  int64
#  7   injuries_indirect  40037 non-null  int64
#  8   deaths_direct      40037 non-null  int64
#  9   deaths_indirect    40037 non-null  int64
#  10  damage_property    31453 non-null  float64
#  11  damage_crops       32222 non-null  float64
#  12  magnitude          25659 non-null  float64
#  13  event_latitude     25669 non-null  float64
#  14  event_longitude    25669 non-null  float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 4.6+ MB

# %%
# cleaning date columns

new_stormcsv['event_begin_time'] = pd.to_datetime(new_stormcsv['event_begin_time'])
new_stormcsv['event_end_time'] = pd.to_datetime(new_stormcsv['event_end_time'])
# Out:
# <ipython-input-6-5d2f0f95d151>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_stormcsv['event_begin_time'] = pd.to_datetime(new_stormcsv['event_begin_time'])
# <ipython-input-6-5d2f0f95d151>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_stormcsv['event_end_time'] = pd.to_datetime(new_stormcsv['event_end_time'])

# %%
new_stormcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40037 entries, 0 to 40036
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_id           40037 non-null  int64
#  1   state              40037 non-null  object
#  2   event_type         40037 non-null  object
#  3   event_begin_time   40037 non-null  datetime64[ns]
#  4   event_timezone     40037 non-null  object
#  5   event_end_time     40037 non-null  datetime64[ns]
#  6   injuries_direct    40037 non-null  int64
#  7   injuries_indirect  40037 non-null  int64
#  8   deaths_direct      40037 non-null  int64
#  9   deaths_indirect    40037 non-null  int64
#  10  damage_property    31453 non-null  float64
#  11  damage_crops       32222 non-null  float64
#  12  magnitude          25659 non-null  float64
#  13  event_latitude     25669 non-null  float64
#  14  event_longitude    25669 non-null  float64
# dtypes: datetime64[ns](2), float64(5), int64(5), object(3)
# memory usage: 4.6+ MB

# %%
# Combining injury and death columns to be one

new_stormcsv['Injuries'] = new_stormcsv['injuries_direct'] + new_stormcsv['injuries_indirect']
new_stormcsv['Deaths'] = new_stormcsv['deaths_direct'] + new_stormcsv['deaths_indirect']
# new_stormcsv['event_month'] = dt.datetime.strftime(new_stormcsv['event_begin_time'], "%m")
new_stormcsv['event_month'] = new_stormcsv['event_begin_time'].dt.month
new_stormcsv.tail(30)
# Out:
# <ipython-input-8-5c9a2ca17e29>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new
# 40009       34.0         24.6280         -81.1090         0       0
# 40010       38.0         24.7200         -81.9200         0       0
# 40011       35.0         24.4560         -81.8770         0       0
# 40012       39.0         24.8500         -80.6200         0       0
# 40013       36.0         24.4560         -81.8770         0       0
# 40014       34.0         24.4560         -81.8770         0       0
# 40015       34.0         24.7200         -81.9200         0       0
# 40016       35.0         24.5532         -81.7886         0       0
# 40017       35.0         24.5638         -81.7343         0       0
# 40018       35.0         24.8500         -80.6200         0       0
# 40019       35.0         24.4560         -81.8770         0       0
# 40020       35.0         24.8500         -80.6200         0       0
# 40021       34.0         24.8430         -80.8620         0       0
# 40022       34.0         24.6280         -81.1090         0       0
# 40023       41.0         30.5426         -87.9053         0       0
# 40024       37.0         30.4737         -87.1599         0       0
# 40025       55.0         30.2223         -88.0188         0       0
# 40026       50.0         30.6879         -88.0368         0       0
# 40027       34.0         30.3600         -87.0800         0       0
# 40028       40.0         30.6198         -88.0578         0       0
# 40029       36.0         30.3789         -86.4157         0       0
# 40030       37.0         30.4301         -87.9135         0       0
# 40031       43.0         30.3900         -86.5900         0       0
# 40032       37.0         30.4767         -86.3263         0       0
# 40033       41.0         30.6904         -88.0369         0       0
# 40034       35.0         30.6174         -88.0554         0       0
# 40035       36.0         30.2226         -88.0171         0       0
# 40036       34.0         30.4855         -86.4598         0       0
#
#        event_month
# 40007            7
# 40008            7
# 40009            7
# 40010            7
# 40011            7
# 40012            7
# 40013            7
# 40014            7
# 40015            7
# 40016            7
# 40017            7
# 40018            7
# 40019            7
# 40020            7
# 40021            7
# 40022            7
# 40023            7
# 40024            7
# 40025            7
# 40026            7
# 40027            7
# 40028            7
# 40029            7
# 40030            7
# 40031            7
# 40032            7
# 40033            7
# 40034            7
# 40035            7
# 40036            7

# %%
new_stormcsv.columns
# Out:
# Index(['event_id', 'state', 'event_type', 'event_begin_time', 'event_timezone',
#        'event_end_time', 'injuries_direct', 'injuries_indirect',
#        'deaths_direct', 'deaths_indirect', 'damage_property', 'damage_crops',
#        'magnitude', 'event_latitude', 'event_longitude', 'Injuries', 'Deaths',
#        'event_month'],
#       dtype='object')

# %%
clean_storm = new_stormcsv[['event_id', 'state', 'event_type', 'event_month', 'event_begin_time', 'event_timezone',
       'event_end_time', 'Injuries', 'Deaths', 'damage_property', 'damage_crops',
       'magnitude', 'event_latitude', 'event_longitude']]
clean_storm.head()
# Out:
#    event_id     state event_type  event_month    event_begin_time  \
# 0    865452  Oklahoma       hail            1 2020-01-10 11:35:00
# 1    865453  Oklahoma       hail            1 2020-01-10 11:36:00
# 2    865454  Oklahoma       hail            1 2020-01-10 11:38:00
# 3    865455  Oklahoma       hail            1 2020-01-10 15:02:00
# 4    865712     Texas       hail            1 2020-01-10 19:40:00
#
#   event_timezone      event_end_time  Injuries  Deaths  damage_property  \
# 0          CST-6 2020-01-10 11:35:00         0       0              0.0
# 1          CST-6 2020-01-10 11:36:00         0       0              0.0
# 2          CST-6 2020-01-10 11:38:00         0       0              0.0
# 3          CST-6 2020-01-10 15:02:00         0       0          15000.0
# 4          CST-6 2020-01-10 19:40:00         0       0              0.0
#
#    damage_crops  magnitude  event_latitude  event_longitude
# 0           0.0       1.00         36.1514         -95.9460
# 1           0.0       1.00         36.0690         -95.9585
# 2           0.0       0.75         36.1790         -95.9500
# 3           0.0       1.75         35.9106         -94.9710
# 4           0.0       0.75         30.2400         -98.1500

# %%
# column renamings

clean_storm = clean_storm.rename(columns={'Injuries':'total_injuries', 'Deaths':'total_deaths'})
clean_storm.head()
# Out:
#    event_id     state event_type  event_month    event_begin_time  \
# 0    865452  Oklahoma       hail            1 2020-01-10 11:35:00
# 1    865453  Oklahoma       hail            1 2020-01-10 11:36:00
# 2    865454  Oklahoma       hail            1 2020-01-10 11:38:00
# 3    865455  Oklahoma       hail            1 2020-01-10 15:02:00
# 4    865712     Texas       hail            1 2020-01-10 19:40:00
#
#   event_timezone      event_end_time  total_injuries  total_deaths  \
# 0          CST-6 2020-01-10 11:35:00               0             0
# 1          CST-6 2020-01-10 11:36:00               0             0
# 2          CST-6 2020-01-10 11:38:00               0             0
# 3          CST-6 2020-01-10 15:02:00               0             0
# 4          CST-6 2020-01-10 19:40:00               0             0
#
#    damage_property  damage_crops  magnitude  event_latitude  event_longitude
# 0              0.0           0.0       1.00         36.1514         -95.9460
# 1              0.0           0.0       1.00         36.0690         -95.9585
# 2              0.0           0.0       0.75         36.1790         -95.9500
# 3          15000.0           0.0       1.75         35.9106         -94.9710
# 4              0.0           0.0       0.75         30.2400         -98.1500

# %%
clean_storm.dropna()
clean_storm.head()
# Out:
#    event_id     state event_type  event_month    event_begin_time  \
# 0    865452  Oklahoma       hail            1 2020-01-10 11:35:00
# 1    865453  Oklahoma       hail            1 2020-01-10 11:36:00
# 2    865454  Oklahoma       hail            1 2020-01-10 11:38:00
# 3    865455  Oklahoma       hail            1 2020-01-10 15:02:00
# 4    865712     Texas       hail            1 2020-01-10 19:40:00
#
#   event_timezone      event_end_time  total_injuries  total_deaths  \
# 0          CST-6 2020-01-10 11:35:00               0             0
# 1          CST-6 2020-01-10 11:36:00               0             0
# 2          CST-6 2020-01-10 11:38:00               0             0
# 3          CST-6 2020-01-10 15:02:00               0             0
# 4          CST-6 2020-01-10 19:40:00               0             0
#
#    damage_property  damage_crops  magnitude  event_latitude  event_longitude
# 0              0.0           0.0       1.00         36.1514         -95.9460
# 1              0.0           0.0       1.00         36.0690         -95.9585
# 2              0.0           0.0       0.75         36.1790         -95.9500
# 3          15000.0           0.0       1.75         35.9106         -94.9710
# 4              0.0           0.0       0.75         30.2400         -98.1500

# %%
# # linking to StormsDB on SQL
# conn = "postgres:postgres@localhost:5432/storms_db"
# engine = create_engine(f'postgresql://{conn}')

# %%
# engine.table_names()

# %%
# clean_storm.to_sql(name='storms', con = engine, if_exists = 'replace', index = False)

# %%
#Run a query
# pd.read_sql_query('select * from storms limit 10', con = engine)

# %%
clean_storm.to_json(r'clean_storm.json',orient='table')

# %%
clean_storm.head()
# Out:
#    event_id     state event_type  event_month    event_begin_time  \
# 0    865452  Oklahoma       hail            1 2020-01-10 11:35:00
# 1    865453  Oklahoma       hail            1 2020-01-10 11:36:00
# 2    865454  Oklahoma       hail            1 2020-01-10 11:38:00
# 3    865455  Oklahoma       hail            1 2020-01-10 15:02:00
# 4    865712     Texas       hail            1 2020-01-10 19:40:00
#
#   event_timezone      event_end_time  total_injuries  total_deaths  \
# 0          CST-6 2020-01-10 11:35:00               0             0
# 1          CST-6 2020-01-10 11:36:00               0             0
# 2          CST-6 2020-01-10 11:38:00               0             0
# 3          CST-6 2020-01-10 15:02:00               0             0
# 4          CST-6 2020-01-10 19:40:00               0             0
#
#    damage_property  damage_crops  magnitude  event_latitude  event_longitude
# 0              0.0           0.0       1.00         36.1514         -95.9460
# 1              0.0           0.0       1.00         36.0690         -95.9585
# 2              0.0           0.0       0.75         36.1790         -95.9500
# 3          15000.0           0.0       1.75         35.9106         -94.9710
# 4              0.0           0.0       0.75         30.2400         -98.1500

# %%
# Making new group_by dataframe to summarize our data by state and month and get counts for each category to use for our bar chart
# Need count by state and month of event_id
storm_group_bar = clean_storm.groupby(["state","event_month"]).count()['event_id']
storm_group_bardf = storm_group.to_frame()
storm_group_bardf.head(20)
# Out:
#                             event_id
# state          event_month
# Alabama        1                 157
#                2                 124
#                3                  96
#                4                 390
#                5                 101
#                6                 101
#                7                 134
# Alaska         1                  59
#                2                  60
#                3                  24
#                4                  22
#                5                   2
#                7                   1
# American samoa 1                   3
#                2                  14
#                3                   1
#                4                   1
#                6                   2
#                7                   1
# Arizona        1                   2

# %%
clean_storm.columns
# Out:
# Index(['event_id', 'state', 'event_type', 'event_month', 'event_begin_time',
#        'event_timezone', 'event_end_time', 'total_injuries', 'total_deaths',
#        'damage_property', 'damage_crops', 'magnitude', 'event_latitude',
#        'event_longitude'],
#       dtype='object')

# %%
# Creating 2nd grouped dataframe to see counts of below categories by state
# Need count by state and event_type

storm_group_pie = clean_storm.groupby(["state","event_type"]).count()['event_id']
storm_group_piedf = storm_group_pie.to_frame()
storm_group_piedf.head(20)
# Out:
#                                  event_id
# state   event_type
# Alabama flash flood                    77
#         flood                          40
#         frost/freeze                    4
#         hail                           57
#         heat                           11
#         heavy rain                      1
#         high wind                      12
#         lightning                       4
#         storm surge/tide                4
#         strong wind                     8
#         thunderstorm wind             806
#         tornado                        71
#         tropical storm                  3
#         winter weather                  5
# Alaska  avalanche                       3
#         blizzard                       53
#         cold/wind chill                 7
#         extreme cold/wind chill         1
#         flood                           7
#         heavy snow                     57

# %%
# Creating 3rd grouped dataframe to see counts of below categories by state
# Need count by state with only 4 damage columns (total deaths, total injuries, damage property, damage crops)
# Need count by state and event_type

storm_group_bubblepie = clean_storm.groupby("state").count()['event_type'].sum()[['total_injuries', 'total_deaths',
       'damage_property', 'damage_crops']]
storm_group_bubblepie.head(20)
